# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import tukey_hsd

from pathlib import Path
from collections import OrderedDict, defaultdict
from functools import partial
from multiprocessing import Pool, Manager

import lib
from lib import env
from lib.prelude import *

# %%
DETAILS = ['task_type', 'n_objects', 'n_features']


def collect_outputs(dir_, output_filter_fn):
    # output_filter_fn: output_dir -> bool
    if isinstance(output_filter_fn, int):
        output_filter_fn = [str(x) for x in range(output_filter_fn)]
    if output_filter_fn is None:
        output_filter_fn = lambda x: True
    elif isinstance(output_filter_fn, list):
        assert all(isinstance(x, str) for x in output_filter_fn)
        valid_names = output_filter_fn
        output_filter_fn = lambda x: x.name in valid_names
    assert callable(output_filter_fn)

    outputs = []
    dir_ = lib.get_path(dir_)
    if dir_.exists():
        for config_path in dir_.rglob('**/*'):
            if config_path.name.endswith(".toml"): continue
            path = config_path.with_suffix('')
            if (
                path.is_dir()
                and (path / 'DONE').exists()
                and output_filter_fn(path.relative_to(lib.PROJ))
            ):
                outputs.append(path)
    return outputs


def load_record(output, key, subkey):
    output = lib.get_path(output)
    report = lib.load_report(output)
    if Path(report['program']).stem == 'tune':
        report = report['best']

    name = output.parent.name
    if "ensemble" in name:
        single_report = lib.load_report(output.parent.parent/name.replace("ensemble_5", "evaluation/0"))
    else:
        single_report = report


    dataset = Path(single_report["config"]["data"]["path"]).name


    dataset_info = lib.load_dataset_info(dataset)
    record = {
        'dataset': dataset_info['name'],
        'task_type': dataset_info['task_type'],
        'n_objects': dataset_info['size'],
        'n_features': dataset_info['n_num_features'] + dataset_info['n_cat_features'],
        'key': (
            f'{Path(program).stem} | {output.relative_to(lib.PROJ).parent.name}'
            if key is None
            else key
        ),
        'subkey': subkey,
    }
    for part in lib.Part:
        part = part.value
        if part in report['metrics']:
            record[f'{part}_score'] = report['metrics'][part]['score']
        try:
            record[f'val_out_score'] = report['metrics']['val_out']['score']
            record[f'test_out_score'] = report['metrics']['test_out']['score']
        except:
            pass
    return record


def sort(df, by):
    if isinstance(by, str):
        by = [by]
    return df.sort_values(
        ['n_objects', 'dataset'] + by,
        ascending=[True, True] + ['score' not in x for x in by],
    ).reset_index(drop=True)


def make_df(records):
    df = pd.DataFrame(records)
    return df


def format_scores(df, precision):
    def f(record):
        if record['task_type'] == lib.TaskType.REGRESSION.value:
            for part in lib.Part:
                for suffix in 'best', 'score':
                    if isinstance(part, str): key = f'{part}_{suffix}'
                    else: key = f'{part.value}_{suffix}'
                    if key in record:
                        record[key] *= -1
        for k, v in list(record.items()):
            if isinstance(v, float):
                if record['dataset'] == 'House 16H': v = v / 10_000
                record[k] = round(v, precision)
        return record

    return df.apply(f, axis=1)


def drop_details(df):
    return df.drop(columns=DETAILS)


def drop_std(df):
    return df.drop(columns=[x for x in df.columns if x.endswith('_std')])


def build_df(records_info, precision=None, details=True):
    # (sub_)key_fn: Union[None, str, Callable[[output_dir], str]]
    records = []
    for dir_, output_filter_fn, key_fn, subkey_fn in records_info:
        for output in collect_outputs(dir_, output_filter_fn):
            key, subkey = [
                None if fn is None else fn if isinstance(fn, str) else fn(output)
                for fn in [key_fn, subkey_fn]
            ]
            record = load_record(output, key, subkey)
            if record is not None:
                records.append(record)

    if not records:
        raise RuntimeError('No records are available!')
    df = make_df(records)
    if precision is not None:
        df = format_scores(df, precision)
    if not details:
        df = drop_details(df)
    return df


def aggregate(df):
    aggrs = dict(
        test_score=('test_score', 'mean'),
        test_std=('test_score', 'std'),
        val_score=('val_score', 'mean'),
        val_std=('val_score', 'std'),
        train_score=('train_score', 'mean'),
        train_std=('train_score', 'std'),
        count=('test_score', 'count'),
    )
    for x in DETAILS:
        if x in df.columns:
            aggrs[x] = (x, 'first')
    df = df.groupby(['dataset', 'key']).agg(**aggrs)
    df['count'] = df['count'].astype(int)
    return df.reset_index().fillna(0.0)

def get_ranks_by_dataset(dataset, df, pvalue_threshold):
    dataset_results = df[df['dataset'] == dataset][['dataset', 'key', 'test_score']].\
                          groupby('key').apply(lambda x : np.array(x['test_score']))
    pvalues = tukey_hsd(*list(dataset_results.values)).pvalue
    key_to_idx = {}
    for i, key in enumerate(dataset_results.index):
        key_to_idx[key] = i

    means = df[df['dataset'] == dataset][['dataset', 'key', 'test_score']].\
            groupby('key')['test_score'].mean()

    sorted_res = means.sort_values(ascending=False)
    prev = None
    first = None
    rank = 1
    ranks = []

    for key in sorted_res.index:
        if first is not None:
            first_idx = key_to_idx[first]
            cur_idx = key_to_idx[key]
            if pvalues[cur_idx][first_idx] < pvalue_threshold:
                rank += 1
                first = key
        else:
            first = key
        ranks.append(rank)
    return ranks, sorted_res.index


def generate_ranks(df, pvalue_threshold=0.05):
    datasets = df.dataset.unique()
    results = defaultdict(lambda : defaultdict())
    
    f = partial(get_ranks_by_dataset, df=df, pvalue_threshold=pvalue_threshold)
    with Pool(len(datasets)) as p:
        result = p.map(f, datasets)
    for i in range(len(datasets)):
        for rank, key in zip(*result[i]):
            results[datasets[i]][key] = rank
    ranks = pd.DataFrame(results)
    ranks.columns = ranks.columns.map(lambda x: x.split()[0].split("-")[0])
    datasets_cols = list(ranks.columns.map(lambda x: x.split()[0].split("-")[0]))
    ranks['AVG'] = ranks.mean(1)
    ranks['STD'] = ranks.std(1)
    ranks = ranks[['AVG', 'STD'] + datasets_cols]
    return ranks.sort_values(by=['AVG'])

# %%
def display_results(pretrains, models, additional=None, ensemble=False, gbdt=True, test_ranks=True, datasets=DATASETS):
    results = []

    kind = "ensemble_5" if ensemble else "evaluation"

    for name, model in itertools.product(pretrains, models):
        p = lib.EXP/name/model
        if p.exists():
            results.append((p, f"{model.upper()} ({name})"))


    results = sum([
        [
            (r/d/f"3_{kind}", 15, n, None)
            for d in datasets
        ]
        for r,n in results
    ], [])

    if gbdt:
        results += [
            (lib.EXP/"catboost"/d/f"0_{kind}", 15, "Catboost", None)
            for d in datasets
        ]

    if additional:
        results += [
            (lib.EXP/a.format(d, kind), 15, n, None) for a,n in additional for d in datasets
        ]

    df = build_df(results)                       

    if test_ranks:
        df_ranks = generate_ranks(df)

    df = aggregate(df)
    df = sort(df, 'test_score')
    df = format_scores(df, 4)
    df = df.set_index(['dataset', 'key'])

    if not test_ranks:
        df_ranks = deepcopy(df).reset_index()
        df_ranks.loc[df_ranks["task_type"] == "regression", "test_score"] *= -1
        df_ranks = df_ranks.pivot("key", "dataset", "test_score")
        df_ranks.columns = df_ranks.columns.map(lambda x: x.split()[0].split("-")[0])
        df_ranks = df_ranks.rank(0, ascending=False)
        df_ranks["avg"] = df_ranks.mean(1)
        df_ranks["std"] = df_ranks.std(1)
        df_ranks.insert(0, "avg", df_ranks.pop("avg"))
        df_ranks.insert(1, "std", df_ranks.pop("std"))
        df_ranks = df_ranks.sort_values("avg")

    display(df_ranks)
    display(df)

# %% [markdown]
# # Results

# %%
# vanilla pretrains
display_results(
    pretrains = [
        "scratch",
        "mask",
        "rec",
        "sup",
        "contrastive",

        "rec-target",
        "mask-target",

        "mask-sup",
        "rec-sup",
    ],
    models = [
#         "resnet",
        "mlp",
#         "transformer",
        "mlp-p-lr",
        "mlp-t-lr",
    ],
    datasets = DATASETS,
    ensemble = True,
    test_ranks = True,
    gbdt = True
)
# Out:
#                              AVG       STD  Gesture  Churn  California  House  \
# MLP-P-LR (rec-sup)      2.454545  1.558766        1      2           3      2
# MLP-P-LR (mask-target)  2.545455  1.437399        2      1           1      2
# MLP-P-LR (mask)         2.636364  1.431638        1      2           3      1
# MLP-P-LR (rec)          2.636364  1.298442        3      4           2      2
# MLP-T-LR (mask)         2.727273  1.135454        4      1           2      1
# MLP-T-LR (mask-target)  2.909091  1.781447        4      1           1      1
# MLP-T-LR (rec)          2.909091  1.378705        3      3           2      3
# MLP-T-LR (rec-sup)      3.000000  1.595448        2      1           3      3
# MLP-P-LR (mask-sup)     3.181818  1.402477        1      1           3      3
# MLP (mask-target)       3.272727  1.813631        2      3           2      2
# MLP-T-LR (rec-target)   3.272727  1.482682        3      1           4      3
# MLP-P-LR (rec-target)   3.272727  1.542778        2      3           4      2
# Catboost                3.363636  2.185603        3      2           4      4
# MLP-T-LR (mask-sup)     3.363636  1.431638        3      1           3      4
# MLP (rec-sup)           3.363636  1.720081        2      3           3      2
# MLP (mask-sup)          3.454545  1.776802        2      3           2      3
# MLP-P-LR (scratch)      3.545455  1.671343        3      2           6      2
# MLP (rec-target)        3.909091  1.880742        4      4           4      1
# MLP (mask)              4.090909  1.975051        1      3           5      3
# MLP (rec)               4.181818  1.748671        4      4           3      2
# MLP (contrastive)       4.272727  2.415515        2      4           4      2
# MLP-T-LR (scratch)      4.636364  1.772144        5      1           5      3
# MLP (scratch)           6.272727  1.710444        5      5           7      3
#
#                         Otto  Higgs  Facebook  Adult  Shifts  Covertype  MSLR
# MLP-P-LR (rec-sup)         2      7         2      1       2          2     3
# MLP-P-LR (mask-target)     4      1         4      1       5          3     4
# MLP-P-LR (mask)            3      1         5      2       5          2     4
# MLP-P-LR (rec)             3      6         2      2       2          1     2
# MLP-T-LR (mask)            2      2         4      3       4          3     4
# MLP-T-LR (mask-target)     4      1         5      1       5          4     5
# MLP-T-LR (rec)             4      6         1      4       1          3     2
# MLP-T-LR (rec-sup)         1      6         5      3       2          2     5
# MLP-P-LR (mask-sup)        5      5         4      3       5          2     3
# MLP (mask-target)          3      1         6      5       1          6     5
# MLP-T-LR (rec-target)      3      7         4      2       3          4     2
# MLP-P-LR (rec-target)      5      5         1      2       6          2     4
# Catboost                   2      8         3      2       1          7     1
# MLP-T-LR (mask-sup)        4      4         5      3       3          1     6
# MLP (rec-sup)              1      5         6      6       1          4     4
# MLP (mask-sup)             1      4         7      5       2          3     6
# MLP-P-LR (scratch)         6      6         4      2       4          2     2
# MLP (rec-target)           2      5         6      8       3          4     2
# MLP (mask)                 2      3         6      6       3          8     5
# MLP (rec)                  3      7         6      7       2          5     3
# MLP (contrastive)          2      4         7      7       1          9     5
# MLP-T-LR (scratch)         6      8         5      3       5          4     6
# MLP (scratch)              5      9         8      8       5          7     7
#                                                     test_score  test_std  \
# dataset                     key
# Gesture Phase               MLP-P-LR (rec-sup)          0.7369    0.0025
#                             MLP-P-LR (mask-sup)         0.7325    0.0025
#                             MLP-P-LR (mask)             0.7252    0.0060
#                             MLP (mask)                  0.7217    0.0020
#                             MLP-P-LR (mask-target)      0.7190    0.0044
#                             MLP (mask-sup)              0.7158    0.0070
#                             MLP (mask-target)           0.7090    0.0090
#                             MLP (rec-sup)               0.7089    0.0046
#                             MLP (contrastive)           0.7082    0.0054
#                             MLP-P-LR (rec-target)       0.7055    0.0029
#                             MLP-T-LR (rec-sup)          0.7050    0.0031
#                             MLP-T-LR (mask-sup)         0.6982    0.0050
#                             MLP-P-LR (rec)              0.6976    0.0019
#                             MLP-P-LR (scratch)          0.6954    0.0046
#                             MLP-T-LR (rec)              0.6943    0.0046
#                             MLP-T-LR (rec-target)       0.6933    0.0031
#                             Catboost                    0.6920    0.0023
#                             MLP (rec)                   0.6788    0.0025
#                             MLP-T-LR (mask)             0.6786    0.0058
#                             MLP (rec-target)            0.6775    0.0058
#                             MLP-T-LR (mask-target)      0.6727    0.0013
#                             MLP-T-LR (scratch)          0.6619    0.0094
#                             MLP (scratch)               0.6560    0.0073
# Churn Modelling             MLP-P-LR (mask-sup)         0.8686    0.0004
#                             MLP-T-LR (mask)             0.8685    0.0003
#                             MLP-T-LR (mask-target)      0.8679    0.0006
#                             MLP-T-LR (scratch)          0.8675    0.0006
#                             MLP-T-LR (rec-target)       0.8662    0.0004
#                             MLP-T-LR (mask-sup)         0.8658    0.0014
#                             MLP-P-LR (mask-target)      0.8656    0.0005
#                             MLP-T-LR (rec-sup)          0.8656    0.0006
#                             MLP-P-LR (mask)             0.8652    0.0009
#                             MLP-P-LR (scratch)          0.8645    0.0009
#                             Catboost                    0.8641    0.0001
#                             MLP-P-LR (rec-sup)          0.8625    0.0017
#                             MLP-P-LR (rec-target)       0.8618    0.0003
#                             MLP-T-LR (rec)              0.8607    0.0002
#                             MLP (mask-target)           0.8604    0.0020
#                             MLP (mask)                  0.8594    0.0008
#                             MLP (rec-sup)               0.8587    0.0022
#                             MLP (mask-sup)              0.8586    0.0014
#                             MLP-P-LR (rec)              0.8574    0.0019
#                             MLP (rec-target)            0.8573    0.0005
#                             MLP (contrastive)           0.8568    0.0011
#                             MLP (rec)                   0.8559    0.0003
#                             MLP (scratch)               0.8515    0.0006
# California Housing          MLP-P-LR (mask-target)      0.4069    0.0010
#                             MLP-T-LR (mask-target)      0.4099    0.0010
#                             MLP-T-LR (mask)             0.4132    0.0012
#                             MLP (mask-target)           0.4141    0.0014
#                             MLP-T-LR (rec)              0.4142    0.0019
#                             MLP (mask-sup)              0.4180    0.0028
#                             MLP-P-LR (rec)              0.4184    0.0015
#                             MLP (rec-sup)               0.4194    0.0026
#                             MLP-P-LR (mask)             0.4210    0.0022
#                             MLP-T-LR (mask-sup)         0.4215    0.0011
#                             MLP-P-LR (mask-sup)         0.4237    0.0011
#                             MLP-P-LR (rec-sup)          0.4239    0.0012
#                             MLP (rec)                   0.4239    0.0001
#                             MLP-T-LR (rec-sup)          0.4245    0.0006
#                             Catboost                    0.4295    0.0014
#                             MLP-P-LR (rec-target)       0.4308    0.0018
#                             MLP-T-LR (rec-target)       0.4321    0.0007
#                             MLP (rec-target)            0.4332    0.0014
#                             MLP (contrastive)           0.4342    0.0050
#                             MLP (mask)                  0.4366    0.0010
#                             MLP-T-LR (scratch)          0.4375    0.0010
#                             MLP-P-LR (scratch)          0.4540    0.0015
#                             MLP (scratch)               0.4820    0.0036
# House 16H                   MLP-T-LR (mask-target)      2.8942    0.0231
#                             MLP-P-LR (mask)             2.9214    0.0133
#                             MLP (rec-target)            2.9256    0.0286
#                             MLP-T-LR (mask)             2.9302    0.0158
#                             MLP (mask-target)           2.9494    0.0236
#                             MLP (rec-sup)               2.9508    0.0240
#                             MLP (contrastive)           2.9520    0.0055
#                             MLP-P-LR (mask-target)      2.9522    0.0044
#                             MLP-P-LR (scratch)          2.9530    0.0092
#                             MLP-P-LR (rec)              2.9545    0.0100
#                             MLP-P-LR (rec-sup)          2.9643    0.0029
#                             MLP (rec)                   2.9674    0.0085
#                             MLP-P-LR (rec-target)       2.9826    0.0155
#                             MLP (mask)                  3.0255    0.0078
#                             MLP-T-LR (scratch)          3.0282    0.0223
#                             MLP-T-LR (rec)              3.0350    0.0234
#                             MLP-T-LR (rec-target)       3.0446    0.0146
#                             MLP (scratch)               3.0554    0.0104
#                             MLP-P-LR (mask-sup)         3.0554    0.0205
#                             MLP-T-LR (rec-sup)          3.0572    0.0125
#                             MLP (mask-sup)              3.0663    0.0148
#                             MLP-T-LR (mask-sup)         3.0877    0.0062
#                             Catboost                    3.0930    0.0063
# Adult ROC                   MLP-P-LR (mask-target)      0.9299    0.0001
#                             MLP-T-LR (mask-target)      0.9298    0.0000
#                             MLP-P-LR (rec-sup)          0.9293    0.0002
#                             MLP-P-LR (rec-target)       0.9285    0.0002
#                             MLP-P-LR (rec)              0.9284    0.0003
#                             MLP-P-LR (mask)             0.9282    0.0001
#                             MLP-T-LR (rec-target)       0.9282    0.0002
#                             Catboost                    0.9279    0.0002
#                             MLP-P-LR (scratch)          0.9276    0.0001
#                             MLP-T-LR (rec-sup)          0.9274    0.0001
#                             MLP-T-LR (mask)             0.9271    0.0004
#                             MLP-P-LR (mask-sup)         0.9270    0.0003
#                             MLP-T-LR (mask-sup)         0.9269    0.0006
#                             MLP-T-LR (scratch)          0.9265    0.0003
#                             MLP-T-LR (rec)              0.9248    0.0002
#                             MLP (mask-target)           0.9164    0.0006
#                             MLP (mask-sup)              0.9162    0.0002
#                             MLP (mask)                  0.9134    0.0004
#                             MLP (rec-sup)               0.9126    0.0006
#                             MLP (rec)                   0.9121    0.0001
#                             MLP (contrastive)           0.9115    0.0002
#                             MLP (rec-target)            0.9104    0.0003
#                             MLP (scratch)               0.9102    0.0003
# Otto Group Products LogLoss MLP (rec-sup)              -0.4423    0.0011
#                             MLP (mask-sup)             -0.4427    0.0019
#                             MLP-T-LR (rec-sup)         -0.4439    0.0017
#                             MLP (rec-target)           -0.4475    0.0012
#                             MLP-P-LR (rec-sup)         -0.4492    0.0003
#                             MLP-T-LR (mask)            -0.4501    0.0009
#                             Catboost                   -0.4504    0.0004
#                             MLP (contrastive)          -0.4508    0.0008
#                             MLP (mask)                 -0.4509    0.0020
#                             MLP (rec)                  -0.4528    0.0015
#                             MLP-P-LR (rec)             -0.4540    0.0024
#                             MLP-T-LR (rec-target)      -0.4563    0.0030
#                             MLP (mask-target)          -0.4568    0.0007
#                             MLP-P-LR (mask)            -0.4569    0.0010
#                             MLP-P-LR (mask-target)     -0.4577    0.0005
#                             MLP-T-LR (rec)             -0.4585    0.0004
#                             MLP-T-LR (mask-sup)        -0.4597    0.0006
#                             MLP-T-LR (mask-target)     -0.4600    0.0018
#                             MLP-P-LR (rec-target)      -0.4648    0.0011
#                             MLP (scratch)              -0.4670    0.0025
#                             MLP-P-LR (mask-sup)        -0.4678    0.0010
#                             MLP-P-LR (scratch)         -0.4696    0.0009
#                             MLP-T-LR (scratch)         -0.4715    0.0006
# Higgs Small                 MLP-P-LR (mask-target)      0.8283    0.0007
#                             MLP (mask-target)           0.8281    0.0008
#                             MLP-T-LR (mask-target)      0.8268    0.0004
#                             MLP-P-LR (mask)             0.8268    0.0001
#                             MLP-T-LR (mask)             0.8260    0.0016
#                             MLP (mask)                  0.8239    0.0008
#                             MLP (contrastive)           0.8197    0.0001
#                             MLP (mask-sup)              0.8190    0.0002
#                             MLP-T-LR (mask-sup)         0.8182    0.0004
#                             MLP (rec-sup)               0.8172    0.0001
#                             MLP-P-LR (mask-sup)         0.8166    0.0004
#                             MLP-P-LR (rec-target)       0.8165    0.0002
#                             MLP (rec-target)            0.8160    0.0007
#                             MLP-T-LR (rec-sup)          0.8141    0.0008
#                             MLP-P-LR (scratch)          0.8138    0.0010
#                             MLP-P-LR (rec)              0.8129    0.0010
#                             MLP-T-LR (rec)              0.8123    0.0003
#                             MLP-T-LR (rec-target)       0.8120    0.0008
#                             MLP (rec)                   0.8119    0.0003
#                             MLP-P-LR (rec-sup)          0.8107    0.0007
#                             MLP-T-LR (scratch)          0.8078    0.0002
#                             Catboost                    0.8073    0.0001
#                             MLP (scratch)               0.8053    0.0004
# Facebook Comments Volume    MLP-T-LR (rec)              5.0387    0.0226
#                             MLP-P-LR (rec-target)       5.0957    0.0229
#                             MLP-P-LR (rec)              5.1241    0.0306
#                             MLP-P-LR (rec-sup)          5.1241    0.0306
#                             Catboost                    5.2257    0.0159
#                             MLP-P-LR (scratch)          5.3235    0.0403
#                             MLP-T-LR (rec-target)       5.3445    0.0100
#                             MLP-P-LR (mask-sup)         5.3660    0.0136
#                             MLP-T-LR (mask)             5.3705    0.0107
#                             MLP-P-LR (mask-target)      5.3730    0.0221
#                             MLP-T-LR (mask-sup)         5.4068    0.0042
#                             MLP-T-LR (rec-sup)          5.4225    0.0023
#                             MLP-T-LR (scratch)          5.4243    0.0281
#                             MLP-P-LR (mask)             5.4444    0.0067
#                             MLP-T-LR (mask-target)      5.4580    0.0351
#                             MLP (rec-sup)               5.5312    0.0038
#                             MLP (mask-target)           5.5511    0.0088
#                             MLP (rec-target)            5.5548    0.0072
#                             MLP (rec)                   5.5707    0.0178
#                             MLP (mask)                  5.5775    0.0084
#                             MLP (mask-sup)              5.6012    0.0058
#                             MLP (contrastive)           5.6340    0.0173
#                             MLP (scratch)               5.6663    0.0032
# Shifts Weather (small)      Catboost                    1.8006    0.0015
#                             MLP (rec-sup)               1.8008    0.0050
#                             MLP-T-LR (rec)              1.8032    0.0029
#                             MLP (contrastive)           1.8036    0.0035
#                             MLP (mask-target)           1.8091    0.0007
#                             MLP (mask-sup)              1.8101    0.0004
#                             MLP (rec)                   1.8111    0.0018
#                             MLP-T-LR (rec-sup)          1.8112    0.0013
#                             MLP-P-LR (rec-sup)          1.8133    0.0024
#                             MLP-P-LR (rec)              1.8183    0.0031
#                             MLP-T-LR (mask-sup)         1.8241    0.0038
#                             MLP (rec-target)            1.8251    0.0032
#                             MLP (mask)                  1.8282    0.0012
#                             MLP-T-LR (rec-target)       1.8295    0.0030
#                             MLP-P-LR (scratch)          1.8351    0.0019
#                             MLP-T-LR (mask)             1.8358    0.0033
#                             MLP-P-LR (mask-sup)         1.8482    0.0021
#                             MLP-P-LR (mask-target)      1.8487    0.0027
#                             MLP-T-LR (mask-target)      1.8488    0.0052
#                             MLP-P-LR (mask)             1.8497    0.0042
#                             MLP (scratch)               1.8500    0.0013
#                             MLP-T-LR (scratch)          1.8501    0.0011
#                             MLP-P-LR (rec-target)       1.8603    0.0025
# Covertype                   MLP-P-LR (rec)              0.9752    0.0004
#                             MLP-T-LR (mask-sup)         0.9751    0.0002
#                             MLP-P-LR (rec-target)       0.9743    0.0000
#                             MLP-P-LR (rec-sup)          0.9742    0.0003
#                             MLP-T-LR (rec-sup)          0.9742    0.0001
#                             MLP-P-LR (scratch)          0.9740    0.0003
#                             MLP-P-LR (mask-sup)         0.9739    0.0003
#                             MLP-P-LR (mask)             0.9739    0.0003
#                             MLP-T-LR (mask)             0.9733    0.0001
#                             MLP-T-LR (rec)              0.9732    0.0001
#                             MLP-P-LR (mask-target)      0.9731    0.0002
#                             MLP (mask-sup)              0.9728    0.0000
#                             MLP (rec-sup)               0.9726    0.0000
#                             MLP-T-LR (mask-target)      0.9724    0.0003
#                             MLP-T-LR (scratch)          0.9722    0.0002
#                             MLP (rec-target)            0.9721    0.0001
#                             MLP-T-LR (rec-target)       0.9720    0.0001
#                             MLP (rec)                   0.9717    0.0003
#                             MLP (mask-target)           0.9690    0.0001
#                             MLP (scratch)               0.9678    0.0003
#                             Catboost                    0.9674    0.0002
#                             MLP (mask)                  0.9667    0.0001
#                             MLP (contrastive)           0.9640    0.0003
# MSLR-WEB10K (Fold 1)        Catboost                    0.7412    0.0002
#                             MLP (rec-target)            0.7430    0.0001
#                             MLP-P-LR (rec)              0.7430    0.0003
#                             MLP-T-LR (rec)              0.7435    0.0006
#                             MLP-T-LR (rec-target)       0.7437    0.0003
#                             MLP-P-LR (scratch)          0.7437    0.0002
#                             MLP-P-LR (mask-sup)         0.7438    0.0001
#                             MLP-P-LR (rec-sup)          0.7439    0.0001
#                             MLP (rec)                   0.7442    0.0001
#                             MLP-P-LR (mask-target)      0.7448    0.0003
#                             MLP-P-LR (mask)             0.7449    0.0001
#                             MLP-T-LR (mask)             0.7454    0.0001
#                             MLP-P-LR (rec-target)       0.7454    0.0003
#                             MLP (rec-sup)               0.7455    0.0001
#                             MLP (mask-target)           0.7458    0.0002
#                             MLP-T-LR (mask-target)      0.7460    0.0003
#                             MLP-T-LR (rec-sup)          0.7460    0.0005
#                             MLP (mask)                  0.7462    0.0001
#                             MLP (contrastive)           0.7465    0.0002
#                             MLP-T-LR (mask-sup)         0.7465    0.0001
#                             MLP (mask-sup)              0.7468    0.0002
#                             MLP-T-LR (scratch)          0.7470    0.0001
#                             MLP (scratch)               0.7473    0.0001
#
#                                                     val_score  val_std  \
# dataset                     key
# Gesture Phase               MLP-P-LR (rec-sup)         0.7479   0.0057
#                             MLP-P-LR (mask-sup)        0.7498   0.0052
#                             MLP-P-LR (mask)            0.7464   0.0086
#                             MLP (mask)                 0.7525   0.0049
#                             MLP-P-LR (mask-target)     0.7447   0.0079
#                             MLP (mask-sup)             0.7297   0.0022
#                             MLP (mask-target)          0.7329   0.0070
#                             MLP (rec-sup)              0.7293   0.0060
#                             MLP (contrastive)          0.7241   0.0067
#                             MLP-P-LR (rec-target)      0.7287   0.0030
#                             MLP-T-LR (rec-sup)         0.7300   0.0004
#                             MLP-T-LR (mask-sup)        0.7169   0.0048
#                             MLP-P-LR (rec)             0.7297   0.0029
#                             MLP-P-LR (scratch)         0.7272   0.0055
#                             MLP-T-LR (rec)             0.7243   0.0029
#                             MLP-T-LR (rec-target)      0.7179   0.0053
#                             Catboost                   0.7082   0.0006
#                             MLP (rec)                  0.6956   0.0035
#                             MLP-T-LR (mask)            0.7091   0.0029
#                             MLP (rec-target)           0.6975   0.0072
#                             MLP-T-LR (mask-target)     0.6977   0.0026
#                             MLP-T-LR (scratch)         0.6808   0.0041
#                             MLP (scratch)              0.6785   0.0035
# Churn Modelling             MLP-P-LR (mask-sup)        0.8778   0.0003
#                             MLP-T-LR (mask)            0.8786   0.0006
#                             MLP-T-LR (mask-target)     0.8795   0.0004
#                             MLP-T-LR (scratch)         0.8741   0.0006
#                             MLP-T-LR (rec-target)      0.8762   0.0002
#                             MLP-T-LR (mask-sup)        0.8770   0.0008
#                             MLP-P-LR (mask-target)     0.8786   0.0009
#                             MLP-T-LR (rec-sup)         0.8739   0.0005
#                             MLP-P-LR (mask)            0.8783   0.0005
#                             MLP-P-LR (scratch)         0.8744   0.0005
#                             Catboost                   0.8709   0.0002
#                             MLP-P-LR (rec-sup)         0.8771   0.0012
#                             MLP-P-LR (rec-target)      0.8740   0.0004
#                             MLP-T-LR (rec)             0.8740   0.0012
#                             MLP (mask-target)          0.8778   0.0019
#                             MLP (mask)                 0.8751   0.0011
#                             MLP (rec-sup)              0.8740   0.0009
#                             MLP (mask-sup)             0.8724   0.0003
#                             MLP-P-LR (rec)             0.8754   0.0011
#                             MLP (rec-target)           0.8729   0.0011
#                             MLP (contrastive)          0.8705   0.0006
#                             MLP (rec)                  0.8692   0.0008
#                             MLP (scratch)              0.8676   0.0017
# California Housing          MLP-P-LR (mask-target)     0.4163   0.0007
#                             MLP-T-LR (mask-target)     0.4154   0.0010
#                             MLP-T-LR (mask)            0.4173   0.0028
#                             MLP (mask-target)          0.4187   0.0022
#                             MLP-T-LR (rec)             0.4219   0.0008
#                             MLP (mask-sup)             0.4217   0.0021
#                             MLP-P-LR (rec)             0.4243   0.0017
#                             MLP (rec-sup)              0.4262   0.0014
#                             MLP-P-LR (mask)            0.4263   0.0017
#                             MLP-T-LR (mask-sup)        0.4221   0.0022
#                             MLP-P-LR (mask-sup)        0.4220   0.0015
#                             MLP-P-LR (rec-sup)         0.4308   0.0012
#                             MLP (rec)                  0.4288   0.0025
#                             MLP-T-LR (rec-sup)         0.4217   0.0010
#                             Catboost                   0.4327   0.0011
#                             MLP-P-LR (rec-target)      0.4320   0.0016
#                             MLP-T-LR (rec-target)      0.4269   0.0005
#                             MLP (rec-target)           0.4370   0.0030
#                             MLP (contrastive)          0.4316   0.0019
#                             MLP (mask)                 0.4394   0.0019
#                             MLP-T-LR (scratch)         0.4405   0.0013
#                             MLP-P-LR (scratch)         0.4577   0.0018
#                             MLP (scratch)              0.4776   0.0018
# House 16H                   MLP-T-LR (mask-target)     2.6836   0.0237
#                             MLP-P-LR (mask)            2.6215   0.0063
#                             MLP (rec-target)           2.7325   0.0040
#                             MLP-T-LR (mask)            2.6710   0.0217
#                             MLP (mask-target)          2.6711   0.0156
#                             MLP (rec-sup)              2.7482   0.0113
#                             MLP (contrastive)          2.7116   0.0167
#                             MLP-P-LR (mask-target)     2.6702   0.0104
#                             MLP-P-LR (scratch)         2.7232   0.0066
#                             MLP-P-LR (rec)             2.6645   0.0069
#                             MLP-P-LR (rec-sup)         2.6531   0.0189
#                             MLP (rec)                  2.7182   0.0166
#                             MLP-P-LR (rec-target)      2.7157   0.0210
#                             MLP (mask)                 2.7462   0.0123
#                             MLP-T-LR (scratch)         2.8851   0.0115
#                             MLP-T-LR (rec)             2.7637   0.0134
#                             MLP-T-LR (rec-target)      2.7951   0.0148
#                             MLP (scratch)              2.7780   0.0215
#                             MLP-P-LR (mask-sup)        2.7644   0.0204
#                             MLP-T-LR (rec-sup)         2.8625   0.0140
#                             MLP (mask-sup)             2.7593   0.0107
#                             MLP-T-LR (mask-sup)        2.8515   0.0202
#                             Catboost                   2.9928   0.0053
# Adult ROC                   MLP-P-LR (mask-target)     0.9336   0.0002
#                             MLP-T-LR (mask-target)     0.9330   0.0000
#                             MLP-P-LR (rec-sup)         0.9333   0.0003
#                             MLP-P-LR (rec-target)      0.9313   0.0002
#                             MLP-P-LR (rec)             0.9327   0.0005
#                             MLP-P-LR (mask)            0.9318   0.0004
#                             MLP-T-LR (rec-target)      0.9314   0.0002
#                             Catboost                   0.9308   0.0005
#                             MLP-P-LR (scratch)         0.9296   0.0003
#                             MLP-T-LR (rec-sup)         0.9313   0.0002
#                             MLP-T-LR (mask)            0.9312   0.0002
#                             MLP-P-LR (mask-sup)        0.9317   0.0002
#                             MLP-T-LR (mask-sup)        0.9313   0.0003
#                             MLP-T-LR (scratch)         0.9309   0.0005
#                             MLP-T-LR (rec)             0.9306   0.0001
#                             MLP (mask-target)          0.9207   0.0007
#                             MLP (mask-sup)             0.9207   0.0001
#                             MLP (mask)                 0.9173   0.0005
#                             MLP (rec-sup)              0.9160   0.0003
#                             MLP (rec)                  0.9156   0.0004
#                             MLP (contrastive)          0.9154   0.0002
#                             MLP (rec-target)           0.9142   0.0001
#                             MLP (scratch)              0.9143   0.0002
# Otto Group Products LogLoss MLP (rec-sup)             -0.4475   0.0001
#                             MLP (mask-sup)            -0.4448   0.0018
#                             MLP-T-LR (rec-sup)        -0.4446   0.0012
#                             MLP (rec-target)          -0.4541   0.0008
#                             MLP-P-LR (rec-sup)        -0.4509   0.0003
#                             MLP-T-LR (mask)           -0.4534   0.0002
#                             Catboost                  -0.4598   0.0008
#                             MLP (contrastive)         -0.4528   0.0010
#                             MLP (mask)                -0.4521   0.0010
#                             MLP (rec)                 -0.4573   0.0020
#                             MLP-P-LR (rec)            -0.4582   0.0017
#                             MLP-T-LR (rec-target)     -0.4599   0.0013
#                             MLP (mask-target)         -0.4610   0.0012
#                             MLP-P-LR (mask)           -0.4580   0.0006
#                             MLP-P-LR (mask-target)    -0.4604   0.0010
#                             MLP-T-LR (rec)            -0.4623   0.0014
#                             MLP-T-LR (mask-sup)       -0.4596   0.0003
#                             MLP-T-LR (mask-target)    -0.4639   0.0017
#                             MLP-P-LR (rec-target)     -0.4691   0.0005
#                             MLP (scratch)             -0.4745   0.0029
#                             MLP-P-LR (mask-sup)       -0.4690   0.0006
#                             MLP-P-LR (scratch)        -0.4717   0.0008
#                             MLP-T-LR (scratch)        -0.4730   0.0008
# Higgs Small                 MLP-P-LR (mask-target)     0.8328   0.0005
#                             MLP (mask-target)          0.8338   0.0007
#                             MLP-T-LR (mask-target)     0.8331   0.0007
#                             MLP-P-LR (mask)            0.8324   0.0004
#                             MLP-T-LR (mask)            0.8318   0.0014
#                             MLP (mask)                 0.8303   0.0006
#                             MLP (contrastive)          0.8251   0.0004
#                             MLP (mask-sup)             0.8239   0.0003
#                             MLP-T-LR (mask-sup)        0.8247   0.0004
#                             MLP (rec-sup)              0.8234   0.0003
#                             MLP-P-LR (mask-sup)        0.8221   0.0002
#                             MLP-P-LR (rec-target)      0.8226   0.0004
#                             MLP (rec-target)           0.8218   0.0001
#                             MLP-T-LR (rec-sup)         0.8201   0.0006
#                             MLP-P-LR (scratch)         0.8196   0.0003
#                             MLP-P-LR (rec)             0.8202   0.0010
#                             MLP-T-LR (rec)             0.8212   0.0010
#                             MLP-T-LR (rec-target)      0.8208   0.0004
#                             MLP (rec)                  0.8186   0.0006
#                             MLP-P-LR (rec-sup)         0.8186   0.0006
#                             MLP-T-LR (scratch)         0.8140   0.0005
#                             Catboost                   0.8129   0.0001
#                             MLP (scratch)              0.8123   0.0004
# Facebook Comments Volume    MLP-T-LR (rec)             4.7852   0.0412
#                             MLP-P-LR (rec-target)      4.7980   0.0104
#                             MLP-P-LR (rec)             4.8495   0.0236
#                             MLP-P-LR (rec-sup)         4.8495   0.0236
#                             Catboost                   5.0905   0.0125
#                             MLP-P-LR (scratch)         5.0526   0.0706
#                             MLP-T-LR (rec-target)      5.0089   0.0208
#                             MLP-P-LR (mask-sup)        5.0746   0.0064
#                             MLP-T-LR (mask)            5.0564   0.0204
#                             MLP-P-LR (mask-target)     5.0976   0.0117
#                             MLP-T-LR (mask-sup)        5.1214   0.0270
#                             MLP-T-LR (rec-sup)         5.1051   0.0184
#                             MLP-T-LR (scratch)         5.1622   0.0076
#                             MLP-P-LR (mask)            5.1439   0.0196
#                             MLP-T-LR (mask-target)     5.1335   0.0313
#                             MLP (rec-sup)              5.3139   0.0294
#                             MLP (mask-target)          5.3237   0.0283
#                             MLP (rec-target)           5.3389   0.0129
#                             MLP (rec)                  5.3660   0.0114
#                             MLP (mask)                 5.3441   0.0192
#                             MLP (mask-sup)             5.3589   0.0054
#                             MLP (contrastive)          5.4300   0.0261
#                             MLP (scratch)              5.4068   0.0193
# Shifts Weather (small)      Catboost                   1.7978   0.0015
#                             MLP (rec-sup)              1.7983   0.0039
#                             MLP-T-LR (rec)             1.7998   0.0024
#                             MLP (contrastive)          1.8043   0.0033
#                             MLP (mask-target)          1.8072   0.0033
#                             MLP (mask-sup)             1.8072   0.0030
#                             MLP (rec)                  1.8095   0.0017
#                             MLP-T-LR (rec-sup)         1.8039   0.0025
#                             MLP-P-LR (rec-sup)         1.8089   0.0018
#                             MLP-P-LR (rec)             1.8139   0.0047
#                             MLP-T-LR (mask-sup)        1.8222   0.0024
#                             MLP (rec-target)           1.8230   0.0032
#                             MLP (mask)                 1.8293   0.0005
#                             MLP-T-LR (rec-target)      1.8281   0.0030
#                             MLP-P-LR (scratch)         1.8339   0.0034
#                             MLP-T-LR (mask)            1.8389   0.0026
#                             MLP-P-LR (mask-sup)        1.8472   0.0020
#                             MLP-P-LR (mask-target)     1.8485   0.0023
#                             MLP-T-LR (mask-target)     1.8488   0.0034
#                             MLP-P-LR (mask)            1.8495   0.0029
#                             MLP (scratch)              1.8518   0.0017
#                             MLP-T-LR (scratch)         1.8503   0.0020
#                             MLP-P-LR (rec-target)      1.8570   0.0022
# Covertype                   MLP-P-LR (rec)             0.9760   0.0003
#                             MLP-T-LR (mask-sup)        0.9761   0.0003
#                             MLP-P-LR (rec-target)      0.9751   0.0001
#                             MLP-P-LR (rec-sup)         0.9751   0.0002
#                             MLP-T-LR (rec-sup)         0.9752   0.0001
#                             MLP-P-LR (scratch)         0.9743   0.0004
#                             MLP-P-LR (mask-sup)        0.9750   0.0001
#                             MLP-P-LR (mask)            0.9746   0.0002
#                             MLP-T-LR (mask)            0.9743   0.0002
#                             MLP-T-LR (rec)             0.9742   0.0002
#                             MLP-P-LR (mask-target)     0.9740   0.0003
#                             MLP (mask-sup)             0.9733   0.0003
#                             MLP (rec-sup)              0.9730   0.0004
#                             MLP-T-LR (mask-target)     0.9738   0.0002
#                             MLP-T-LR (scratch)         0.9730   0.0002
#                             MLP (rec-target)           0.9728   0.0002
#                             MLP-T-LR (rec-target)      0.9731   0.0001
#                             MLP (rec)                  0.9728   0.0000
#                             MLP (mask-target)          0.9699   0.0003
#                             MLP (scratch)              0.9684   0.0003
#                             Catboost                   0.9683   0.0001
#                             MLP (mask)                 0.9672   0.0004
#                             MLP (contrastive)          0.9651   0.0001
# MSLR-WEB10K (Fold 1)        Catboost                   0.7382   0.0001
#                             MLP (rec-target)           0.7392   0.0001
#                             MLP-P-LR (rec)             0.7402   0.0000
#                             MLP-T-LR (rec)             0.7414   0.0007
#                             MLP-T-LR (rec-target)      0.7404   0.0001
#                             MLP-P-LR (scratch)         0.7402   0.0002
#                             MLP-P-LR (mask-sup)        0.7408   0.0001
#                             MLP-P-LR (rec-sup)         0.7406   0.0001
#                             MLP (rec)                  0.7403   0.0003
#                             MLP-P-LR (mask-target)     0.7414   0.0002
#                             MLP-P-LR (mask)            0.7412   0.0001
#                             MLP-T-LR (mask)            0.7423   0.0005
#                             MLP-P-LR (rec-target)      0.7413   0.0003
#                             MLP (rec-sup)              0.7416   0.0002
#                             MLP (mask-target)          0.7419   0.0002
#                             MLP-T-LR (mask-target)     0.7432   0.0003
#                             MLP-T-LR (rec-sup)         0.7421   0.0002
#                             MLP (mask)                 0.7421   0.0002
#                             MLP (contrastive)          0.7428   0.0003
#                             MLP-T-LR (mask-sup)        0.7434   0.0003
#                             MLP (mask-sup)             0.7422   0.0002
#                             MLP-T-LR (scratch)         0.7432   0.0002
#                             MLP (scratch)              0.7433   0.0000
#
#                                                     train_score  train_std  \
# dataset                     key
# Gesture Phase               MLP-P-LR (rec-sup)           0.9988     0.0002
#                             MLP-P-LR (mask-sup)          0.9986     0.0006
#                             MLP-P-LR (mask)              0.9958     0.0016
#                             MLP (mask)                   0.9916     0.0015
#                             MLP-P-LR (mask-target)       0.9883     0.0010
#                             MLP (mask-sup)               0.9948     0.0003
#                             MLP (mask-target)            0.9777     0.0060
#                             MLP (rec-sup)                0.9948     0.0016
#                             MLP (contrastive)            0.9836     0.0040
#                             MLP-P-LR (rec-target)        0.9836     0.0020
#                             MLP-T-LR (rec-sup)           0.9996     0.0002
#                             MLP-T-LR (mask-sup)          0.9995     0.0002
#                             MLP-P-LR (rec)               0.9947     0.0007
#                             MLP-P-LR (scratch)           0.9875     0.0015
#                             MLP-T-LR (rec)               0.9999     0.0002
#                             MLP-T-LR (rec-target)        1.0000     0.0000
#                             Catboost                     1.0000     0.0000
#                             MLP (rec)                    0.9598     0.0054
#                             MLP-T-LR (mask)              0.9997     0.0001
#                             MLP (rec-target)             0.9565     0.0176
#                             MLP-T-LR (mask-target)       0.9999     0.0001
#                             MLP-T-LR (scratch)           0.9997     0.0002
#                             MLP (scratch)                0.9170     0.0082
# Churn Modelling             MLP-P-LR (mask-sup)          0.8936     0.0009
#                             MLP-T-LR (mask)              0.8903     0.0009
#                             MLP-T-LR (mask-target)       0.8948     0.0017
#                             MLP-T-LR (scratch)           0.8957     0.0016
#                             MLP-T-LR (rec-target)        0.9016     0.0016
#                             MLP-T-LR (mask-sup)          0.8821     0.0021
#                             MLP-P-LR (mask-target)       0.8956     0.0026
#                             MLP-T-LR (rec-sup)           0.9011     0.0016
#                             MLP-P-LR (mask)              0.8962     0.0023
#                             MLP-P-LR (scratch)           0.8885     0.0013
#                             Catboost                     0.8868     0.0014
#                             MLP-P-LR (rec-sup)           0.8952     0.0038
#                             MLP-P-LR (rec-target)        0.8976     0.0010
#                             MLP-T-LR (rec)               0.8932     0.0011
#                             MLP (mask-target)            0.9091     0.0073
#                             MLP (mask)                   0.9079     0.0027
#                             MLP (rec-sup)                0.9121     0.0084
#                             MLP (mask-sup)               0.9018     0.0017
#                             MLP-P-LR (rec)               0.8991     0.0018
#                             MLP (rec-target)             0.9099     0.0014
#                             MLP (contrastive)            0.8993     0.0004
#                             MLP (rec)                    0.9127     0.0025
#                             MLP (scratch)                0.9124     0.0048
# California Housing          MLP-P-LR (mask-target)       0.2858     0.0062
#                             MLP-T-LR (mask-target)       0.2829     0.0059
#                             MLP-T-LR (mask)              0.3023     0.0124
#                             MLP (mask-target)            0.2879     0.0159
#                             MLP-T-LR (rec)               0.2801     0.0078
#                             MLP (mask-sup)               0.2926     0.0151
#                             MLP-P-LR (rec)               0.2719     0.0200
#                             MLP (rec-sup)                0.3077     0.0061
#                             MLP-P-LR (mask)              0.2748     0.0088
#                             MLP-T-LR (mask-sup)          0.3147     0.0119
#                             MLP-P-LR (mask-sup)          0.2912     0.0104
#                             MLP-P-LR (rec-sup)           0.2990     0.0014
#                             MLP (rec)                    0.2825     0.0181
#                             MLP-T-LR (rec-sup)           0.2865     0.0023
#                             Catboost                     0.1996     0.0001
#                             MLP-P-LR (rec-target)        0.2776     0.0133
#                             MLP-T-LR (rec-target)        0.2887     0.0052
#                             MLP (rec-target)             0.3017     0.0203
#                             MLP (contrastive)            0.2773     0.0080
#                             MLP (mask)                   0.3063     0.0047
#                             MLP-T-LR (scratch)           0.3340     0.0064
#                             MLP-P-LR (scratch)           0.3365     0.0115
#                             MLP (scratch)                0.4028     0.0106
# House 16H                   MLP-T-LR (mask-target)       1.0381     0.2004
#                             MLP-P-LR (mask)              1.6084     0.0258
#                             MLP (rec-target)             1.2002     0.1089
#                             MLP-T-LR (mask)              1.3615     0.0877
# ...
#                             MLP (contrastive)           10000          11
#                             MLP (rec)                   10000          11
#                             MLP (scratch)               10000          11
# California Housing          MLP-P-LR (mask-target)      20640           8
#                             MLP-T-LR (mask-target)      20640           8
#                             MLP-T-LR (mask)             20640           8
#                             MLP (mask-target)           20640           8
#                             MLP-T-LR (rec)              20640           8
#                             MLP (mask-sup)              20640           8
#                             MLP-P-LR (rec)              20640           8
#                             MLP (rec-sup)               20640           8
#                             MLP-P-LR (mask)             20640           8
#                             MLP-T-LR (mask-sup)         20640           8
#                             MLP-P-LR (mask-sup)         20640           8
#                             MLP-P-LR (rec-sup)          20640           8
#                             MLP (rec)                   20640           8
#                             MLP-T-LR (rec-sup)          20640           8
#                             Catboost                    20640           8
#                             MLP-P-LR (rec-target)       20640           8
#                             MLP-T-LR (rec-target)       20640           8
#                             MLP (rec-target)            20640           8
#                             MLP (contrastive)           20640           8
#                             MLP (mask)                  20640           8
#                             MLP-T-LR (scratch)          20640           8
#                             MLP-P-LR (scratch)          20640           8
#                             MLP (scratch)               20640           8
# House 16H                   MLP-T-LR (mask-target)      22784          16
#                             MLP-P-LR (mask)             22784          16
#                             MLP (rec-target)            22784          16
#                             MLP-T-LR (mask)             22784          16
#                             MLP (mask-target)           22784          16
#                             MLP (rec-sup)               22784          16
#                             MLP (contrastive)           22784          16
#                             MLP-P-LR (mask-target)      22784          16
#                             MLP-P-LR (scratch)          22784          16
#                             MLP-P-LR (rec)              22784          16
#                             MLP-P-LR (rec-sup)          22784          16
#                             MLP (rec)                   22784          16
#                             MLP-P-LR (rec-target)       22784          16
#                             MLP (mask)                  22784          16
#                             MLP-T-LR (scratch)          22784          16
#                             MLP-T-LR (rec)              22784          16
#                             MLP-T-LR (rec-target)       22784          16
#                             MLP (scratch)               22784          16
#                             MLP-P-LR (mask-sup)         22784          16
#                             MLP-T-LR (rec-sup)          22784          16
#                             MLP (mask-sup)              22784          16
#                             MLP-T-LR (mask-sup)         22784          16
#                             Catboost                    22784          16
# Adult ROC                   MLP-P-LR (mask-target)      48842          14
#                             MLP-T-LR (mask-target)      48842          14
#                             MLP-P-LR (rec-sup)          48842          14
#                             MLP-P-LR (rec-target)       48842          14
#                             MLP-P-LR (rec)              48842          14
#                             MLP-P-LR (mask)             48842          14
#                             MLP-T-LR (rec-target)       48842          14
#                             Catboost                    48842          14
#                             MLP-P-LR (scratch)          48842          14
#                             MLP-T-LR (rec-sup)          48842          14
#                             MLP-T-LR (mask)             48842          14
#                             MLP-P-LR (mask-sup)         48842          14
#                             MLP-T-LR (mask-sup)         48842          14
#                             MLP-T-LR (scratch)          48842          14
#                             MLP-T-LR (rec)              48842          14
#                             MLP (mask-target)           48842          14
#                             MLP (mask-sup)              48842          14
#                             MLP (mask)                  48842          14
#                             MLP (rec-sup)               48842          14
#                             MLP (rec)                   48842          14
#                             MLP (contrastive)           48842          14
#                             MLP (rec-target)            48842          14
#                             MLP (scratch)               48842          14
# Otto Group Products LogLoss MLP (rec-sup)               61878          93
#                             MLP (mask-sup)              61878          93
#                             MLP-T-LR (rec-sup)          61878          93
#                             MLP (rec-target)            61878          93
#                             MLP-P-LR (rec-sup)          61878          93
#                             MLP-T-LR (mask)             61878          93
#                             Catboost                    61878          93
#                             MLP (contrastive)           61878          93
#                             MLP (mask)                  61878          93
#                             MLP (rec)                   61878          93
#                             MLP-P-LR (rec)              61878          93
#                             MLP-T-LR (rec-target)       61878          93
#                             MLP (mask-target)           61878          93
#                             MLP-P-LR (mask)             61878          93
#                             MLP-P-LR (mask-target)      61878          93
#                             MLP-T-LR (rec)              61878          93
#                             MLP-T-LR (mask-sup)         61878          93
#                             MLP-T-LR (mask-target)      61878          93
#                             MLP-P-LR (rec-target)       61878          93
#                             MLP (scratch)               61878          93
#                             MLP-P-LR (mask-sup)         61878          93
#                             MLP-P-LR (scratch)          61878          93
#                             MLP-T-LR (scratch)          61878          93
# Higgs Small                 MLP-P-LR (mask-target)      98049          28
#                             MLP (mask-target)           98049          28
#                             MLP-T-LR (mask-target)      98049          28
#                             MLP-P-LR (mask)             98049          28
#                             MLP-T-LR (mask)             98049          28
#                             MLP (mask)                  98049          28
#                             MLP (contrastive)           98049          28
#                             MLP (mask-sup)              98049          28
#                             MLP-T-LR (mask-sup)         98049          28
#                             MLP (rec-sup)               98049          28
#                             MLP-P-LR (mask-sup)         98049          28
#                             MLP-P-LR (rec-target)       98049          28
#                             MLP (rec-target)            98049          28
#                             MLP-T-LR (rec-sup)          98049          28
#                             MLP-P-LR (scratch)          98049          28
#                             MLP-P-LR (rec)              98049          28
#                             MLP-T-LR (rec)              98049          28
#                             MLP-T-LR (rec-target)       98049          28
#                             MLP (rec)                   98049          28
#                             MLP-P-LR (rec-sup)          98049          28
#                             MLP-T-LR (scratch)          98049          28
#                             Catboost                    98049          28
#                             MLP (scratch)               98049          28
# Facebook Comments Volume    MLP-T-LR (rec)             197080          51
#                             MLP-P-LR (rec-target)      197080          51
#                             MLP-P-LR (rec)             197080          51
#                             MLP-P-LR (rec-sup)         197080          51
#                             Catboost                   197080          51
#                             MLP-P-LR (scratch)         197080          51
#                             MLP-T-LR (rec-target)      197080          51
#                             MLP-P-LR (mask-sup)        197080          51
#                             MLP-T-LR (mask)            197080          51
#                             MLP-P-LR (mask-target)     197080          51
#                             MLP-T-LR (mask-sup)        197080          51
#                             MLP-T-LR (rec-sup)         197080          51
#                             MLP-T-LR (scratch)         197080          51
#                             MLP-P-LR (mask)            197080          51
#                             MLP-T-LR (mask-target)     197080          51
#                             MLP (rec-sup)              197080          51
#                             MLP (mask-target)          197080          51
#                             MLP (rec-target)           197080          51
#                             MLP (rec)                  197080          51
#                             MLP (mask)                 197080          51
#                             MLP (mask-sup)             197080          51
#                             MLP (contrastive)          197080          51
#                             MLP (scratch)              197080          51
# Shifts Weather (small)      Catboost                   397099         123
#                             MLP (rec-sup)              397099         123
#                             MLP-T-LR (rec)             397099         123
#                             MLP (contrastive)          397099         123
#                             MLP (mask-target)          397099         123
#                             MLP (mask-sup)             397099         123
#                             MLP (rec)                  397099         123
#                             MLP-T-LR (rec-sup)         397099         123
#                             MLP-P-LR (rec-sup)         397099         123
#                             MLP-P-LR (rec)             397099         123
#                             MLP-T-LR (mask-sup)        397099         123
#                             MLP (rec-target)           397099         123
#                             MLP (mask)                 397099         123
#                             MLP-T-LR (rec-target)      397099         123
#                             MLP-P-LR (scratch)         397099         123
#                             MLP-T-LR (mask)            397099         123
#                             MLP-P-LR (mask-sup)        397099         123
#                             MLP-P-LR (mask-target)     397099         123
#                             MLP-T-LR (mask-target)     397099         123
#                             MLP-P-LR (mask)            397099         123
#                             MLP (scratch)              397099         123
#                             MLP-T-LR (scratch)         397099         123
#                             MLP-P-LR (rec-target)      397099         123
# Covertype                   MLP-P-LR (rec)             581012          54
#                             MLP-T-LR (mask-sup)        581012          54
#                             MLP-P-LR (rec-target)      581012          54
#                             MLP-P-LR (rec-sup)         581012          54
#                             MLP-T-LR (rec-sup)         581012          54
#                             MLP-P-LR (scratch)         581012          54
#                             MLP-P-LR (mask-sup)        581012          54
#                             MLP-P-LR (mask)            581012          54
#                             MLP-T-LR (mask)            581012          54
#                             MLP-T-LR (rec)             581012          54
#                             MLP-P-LR (mask-target)     581012          54
#                             MLP (mask-sup)             581012          54
#                             MLP (rec-sup)              581012          54
#                             MLP-T-LR (mask-target)     581012          54
#                             MLP-T-LR (scratch)         581012          54
#                             MLP (rec-target)           581012          54
#                             MLP-T-LR (rec-target)      581012          54
#                             MLP (rec)                  581012          54
#                             MLP (mask-target)          581012          54
#                             MLP (scratch)              581012          54
#                             Catboost                   581012          54
#                             MLP (mask)                 581012          54
#                             MLP (contrastive)          581012          54
# MSLR-WEB10K (Fold 1)        Catboost                  1200192         136
#                             MLP (rec-target)          1200192         136
#                             MLP-P-LR (rec)            1200192         136
#                             MLP-T-LR (rec)            1200192         136
#                             MLP-T-LR (rec-target)     1200192         136
#                             MLP-P-LR (scratch)        1200192         136
#                             MLP-P-LR (mask-sup)       1200192         136
#                             MLP-P-LR (rec-sup)        1200192         136
#                             MLP (rec)                 1200192         136
#                             MLP-P-LR (mask-target)    1200192         136
#                             MLP-P-LR (mask)           1200192         136
#                             MLP-T-LR (mask)           1200192         136
#                             MLP-P-LR (rec-target)     1200192         136
#                             MLP (rec-sup)             1200192         136
#                             MLP (mask-target)         1200192         136
#                             MLP-T-LR (mask-target)    1200192         136
#                             MLP-T-LR (rec-sup)        1200192         136
#                             MLP (mask)                1200192         136
#                             MLP (contrastive)         1200192         136
#                             MLP-T-LR (mask-sup)       1200192         136
#                             MLP (mask-sup)            1200192         136
#                             MLP-T-LR (scratch)        1200192         136
#                             MLP (scratch)             1200192         136
